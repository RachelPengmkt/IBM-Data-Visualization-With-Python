# %% [markdown]
# Now you should be ready to proceed with creating the Choropleth map.
#
# As you learned in the Choropleth maps lab, you will need a GeoJSON file that marks the boundaries of the different neighborhoods in San Francisco. In order to save you the hassle of looking for the right file, I already downloaded it for you and I am making it available via this link: https://cocl.us/sanfran_geojson.

# %% [markdown]
# For the map, make sure that:

# %% [markdown]
# it is centred around San Francisco,
#
# you use a zoom level of 12,
#
# you use fill_color = 'YlOrRd',
#
# you define fill_opacity = 0.7,
#
# you define line_opacity=0.2, and,
#
# you define a legend and use the default threshold scale.

# %% [markdown]
# If you follow the lab on Choropleth maps and use the GeoJSON correctly, you should be able to generate the following map:
#
#
# Once you are ready to submit your map, please upload a screenshot of your Choropleth map. (5 marks)

# %% [markdown]
# Once you are ready to submit your map, please upload a screenshot of your Choropleth map. (5 marks)

# %%
import pandas as pd
import numpy as np

# %%
# import the data
sf=pd.read_csv('Police_Department_Incidents_-_Previous_Year__2016_.csv')

# %%
sf
# Out:
#         IncidntNum        Category  \
# 0        120058272     WEAPON LAWS
# 1        120058272     WEAPON LAWS
# 2        141059263        WARRANTS
# 3        160013662    NON-CRIMINAL
# 4        160002740    NON-CRIMINAL
# ...            ...             ...
# 150495   161061000         ASSAULT
# 150496   176000742    NON-CRIMINAL
# 150497   176000758   LARCENY/THEFT
# 150498   176000764   LARCENY/THEFT
# 150499   179002868  OTHER OFFENSES
#
#                                                  Descript DayOfWeek  \
# 0                               POSS OF PROHIBITED WEAPON    Friday
# 1          FIREARM, LOADED, IN VEHICLE, POSSESSION OR USE    Friday
# 2                                          WARRANT ARREST    Monday
# 3                                           LOST PROPERTY   Tuesday
# 4                                           LOST PROPERTY    Friday
# ...                                                   ...       ...
# ...

# %%
sf_s=sf.groupby(['PdDistrict'], sort=0).apply(lambda g: pd.Series({\
                                                                 'Count': g.IncidntNum.count(),\
                                                                 }))

# %%
sf_s.reset_index(level=0, inplace=True)

# %%
sf_s.drop(['PdDistrict'], axis=1)
# Out:
#    Count Neighborhood
# 0  28445     SOUTHERN
# 1  14303      BAYVIEW
# 2   9942   TENDERLOIN
# 3  19503      MISSION
# 4  20100     NORTHERN
# 5  11325      TARAVAL
# 6  11594    INGLESIDE
# 7  17666      CENTRAL
# 8   8922     RICHMOND
# 9   8699         PARK

# %%
sf_s
